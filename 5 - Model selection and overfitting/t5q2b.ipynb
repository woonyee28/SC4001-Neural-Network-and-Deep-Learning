# %%
import torch
from torch import nn
import torchvision
import torchvision.transforms as transforms

import numpy as np

# %%
batch_size = 256
max_epochs = 100

patience = 10
dropouts = 0.1
weight_decay = 0.001

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
train_dataloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
test_dataloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=2)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
class NeuralNetwork(nn.Module):
    def __init__(self, hidden_size=500):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(32*32*3, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, 10),
            nn.Softmax(dim=1)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

# %%
class NeuralNetwork_dropout(nn.Module):
    def __init__(self, hidden_size = 100, drop_out=0.5):
        super(NeuralNetwork_dropout, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(32*32*3, hidden_size),
            nn.ReLU(),
            nn.Dropout(p=drop_out),
            nn.Linear(hidden_size, hidden_size),
            nn.ReLU(),
            nn.Dropout(p=drop_out),
            nn.Linear(hidden_size, hidden_size),
            nn.ReLU(),
            nn.Dropout(p=drop_out),
            nn.Linear(hidden_size, 10),
            nn.Softmax(dim=1)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

# %%
def train_loop(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    train_loss, train_correct = 0, 0
    for batch, (X, y) in enumerate(dataloader):
        # Compute prediction and loss
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item()
        train_correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    
    train_loss /= size
    train_correct /=size

    return train_loss, train_correct

def test_loop(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, test_correct = 0, 0

    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            test_correct += (pred.argmax(1) == y).type(torch.float).sum().item()

    test_loss /= size
    test_correct /= size
    
    return test_loss, test_correct

# %%
class EarlyStopper:
    def __init__(self, patience=10, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.min_validation_loss = np.inf

    def early_stop(self, validation_loss):
        if validation_loss < self.min_validation_loss:
            self.min_validation_loss = validation_loss
            self.counter = 0
        elif validation_loss > (self.min_validation_loss + self.min_delta):
            self.counter += 1
            if self.counter >= self.patience:
                return True
        return False

# %%
model = NeuralNetwork(hidden_size=500)
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters())
early_stopper = EarlyStopper(patience=patience, min_delta=0)

tr_loss, tr_correct = [], []
te_loss, te_correct = [], []
for t in range(max_epochs):
    train_loss, train_correct = train_loop(train_dataloader, model, loss_fn, optimizer)
    test_loss, test_correct = test_loop(test_dataloader, model, loss_fn)
    
    tr_loss.append(train_loss), tr_correct.append(train_correct)
    te_loss.append(test_loss), te_correct.append(test_correct)
    
    
    print(f"Epoch {t+1}: Train_accuracy: {(100*train_correct):>0.2f}%, Train_loss: {train_loss:>8f}, Test_accuracy: {(100*test_correct):>0.2f}%, Test_loss: {test_loss:>8f}")
    
    if early_stopper.early_stop(test_loss): 
        print("Done!")
        break
# Out:
# Epoch 1: Train_accuracy: 33.44%, Train_loss: 0.008304, Test_accuracy: 37.56%, Test_loss: 0.008316
# Epoch 2: Train_accuracy: 38.97%, Train_loss: 0.008100, Test_accuracy: 37.78%, Test_loss: 0.008321
# Epoch 3: Train_accuracy: 39.84%, Train_loss: 0.008068, Test_accuracy: 36.37%, Test_loss: 0.008386
# Epoch 4: Train_accuracy: 40.94%, Train_loss: 0.008027, Test_accuracy: 41.41%, Test_loss: 0.008185
# Epoch 5: Train_accuracy: 42.15%, Train_loss: 0.007985, Test_accuracy: 42.03%, Test_loss: 0.008159
# Epoch 6: Train_accuracy: 42.29%, Train_loss: 0.007982, Test_accuracy: 41.56%, Test_loss: 0.008189
# Epoch 7: Train_accuracy: 41.36%, Train_loss: 0.008020, Test_accuracy: 42.20%, Test_loss: 0.008155
# Epoch 8: Train_accuracy: 41.35%, Train_loss: 0.008021, Test_accuracy: 40.20%, Test_loss: 0.008225
# Epoch 9: Train_accuracy: 42.16%, Train_loss: 0.007992, Test_accuracy: 39.67%, Test_loss: 0.008261
# Epoch 10: Train_accuracy: 40.50%, Train_loss: 0.008058, Test_accuracy: 38.60%, Test_loss: 0.008304
# Epoch 11: Train_accuracy: 40.17%, Train_loss: 0.008070, Test_accuracy: 40.66%, Test_loss: 0.008225
# Epoch 12: Train_accuracy: 39.51%, Train_loss: 0.008096, Test_accuracy: 38.32%, Test_loss: 0.008321
# Epoch 13: Train_accuracy: 38.81%, Train_loss: 0.008124, Test_accuracy: 35.50%, Test_loss: 0.008433
# Epoch 14: Train_accuracy: 38.42%, Train_loss: 0.008138, Test_accuracy: 39.16%, Test_loss: 0.008290
# Epoch 15: Train_accuracy: 38.67%, Train_loss: 0.008132, Test_accuracy: 36.99%, Test_loss: 0.008382
# Epoch 16: Train_accuracy: 36.05%, Train_loss: 0.008234, Test_accuracy: 33.22%, Test_loss: 0.008534
# Epoch 17: Train_accuracy: 34.85%, Train_loss: 0.008281, Test_accuracy: 33.12%, Test_loss: 0.008538
# Done!

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,8))
plt.plot(range(1,len(tr_loss)+1),tr_loss, label='Train Loss')
plt.plot(range(1,len(te_loss)+1),te_loss,label='Validation Loss')

# find position of lowest validation loss
minposs = te_loss.index(min(te_loss))+1 
plt.axvline(minposs, linestyle='--', color='r',label='Early Stopping Checkpoint')

plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
model = NeuralNetwork(hidden_size=500)
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), weight_decay=weight_decay)
early_stopper = EarlyStopper(patience=patience, min_delta=0)

tr1_loss, tr1_correct = [], []
te1_loss, te1_correct = [], []
for t in range(max_epochs):
    train_loss, train_correct = train_loop(train_dataloader, model, loss_fn, optimizer)
    test_loss, test_correct = test_loop(test_dataloader, model, loss_fn)
    
    tr1_loss.append(train_loss), tr1_correct.append(train_correct)
    te1_loss.append(test_loss), te1_correct.append(test_correct)
    
    
    print(f"Epoch {t+1}: Train_accuracy: {(100*train_correct):>0.2f}%, Train_loss: {train_loss:>8f}, Test_accuracy: {(100*test_correct):>0.2f}%, Test_loss: {test_loss:>8f}")
    
    if early_stopper.early_stop(test_loss): 
        print("Done!")
        break
# Out:
# Epoch 1: Train_accuracy: 32.46%, Train_loss: 0.008346, Test_accuracy: 34.18%, Test_loss: 0.008452
# Epoch 2: Train_accuracy: 36.94%, Train_loss: 0.008172, Test_accuracy: 38.82%, Test_loss: 0.008275
# Epoch 3: Train_accuracy: 38.62%, Train_loss: 0.008113, Test_accuracy: 40.17%, Test_loss: 0.008226
# Epoch 4: Train_accuracy: 40.27%, Train_loss: 0.008053, Test_accuracy: 37.37%, Test_loss: 0.008329
# Epoch 5: Train_accuracy: 41.76%, Train_loss: 0.007992, Test_accuracy: 42.42%, Test_loss: 0.008155
# Epoch 6: Train_accuracy: 43.03%, Train_loss: 0.007947, Test_accuracy: 41.60%, Test_loss: 0.008170
# Epoch 7: Train_accuracy: 43.82%, Train_loss: 0.007920, Test_accuracy: 42.74%, Test_loss: 0.008136
# Epoch 8: Train_accuracy: 44.68%, Train_loss: 0.007884, Test_accuracy: 43.91%, Test_loss: 0.008071
# Epoch 9: Train_accuracy: 45.52%, Train_loss: 0.007856, Test_accuracy: 44.80%, Test_loss: 0.008033
# Epoch 10: Train_accuracy: 45.82%, Train_loss: 0.007847, Test_accuracy: 45.42%, Test_loss: 0.008022
# Epoch 11: Train_accuracy: 47.01%, Train_loss: 0.007799, Test_accuracy: 45.41%, Test_loss: 0.008018
# Epoch 12: Train_accuracy: 46.92%, Train_loss: 0.007803, Test_accuracy: 45.30%, Test_loss: 0.008016
# Epoch 13: Train_accuracy: 47.70%, Train_loss: 0.007772, Test_accuracy: 45.33%, Test_loss: 0.008010
# Epoch 14: Train_accuracy: 48.07%, Train_loss: 0.007758, Test_accuracy: 46.55%, Test_loss: 0.007994
# Epoch 15: Train_accuracy: 48.12%, Train_loss: 0.007752, Test_accuracy: 45.31%, Test_loss: 0.008022
# Epoch 16: Train_accuracy: 48.90%, Train_loss: 0.007729, Test_accuracy: 45.92%, Test_loss: 0.007998
# Epoch 17: Train_accuracy: 49.55%, Train_loss: 0.007705, Test_accuracy: 46.61%, Test_loss: 0.007980
# Epoch 18: Train_accuracy: 49.39%, Train_loss: 0.007711, Test_accuracy: 46.43%, Test_loss: 0.007980
# Epoch 19: Train_accuracy: 49.78%, Train_loss: 0.007692, Test_accuracy: 46.92%, Test_loss: 0.007956
# Epoch 20: Train_accuracy: 50.26%, Train_loss: 0.007679, Test_accuracy: 47.90%, Test_loss: 0.007929
# Epoch 21: Train_accuracy: 50.53%, Train_loss: 0.007669, Test_accuracy: 46.77%, Test_loss: 0.007965
loss))+1 
plt.axvline(minposs, linestyle='--', color='r',label='Early Stopping Checkpoint')

plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
model = NeuralNetwork_dropout(hidden_size=500, drop_out = dropouts)
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters())
early_stopper = EarlyStopper(patience=patience, min_delta=0)

tr2_loss, tr2_correct = [], []
te2_loss, te2_correct = [], []
for t in range(max_epochs):
    train_loss, train_correct = train_loop(train_dataloader, model, loss_fn, optimizer)
    test_loss, test_correct = test_loop(test_dataloader, model, loss_fn)
    
    tr2_loss.append(train_loss), tr2_correct.append(train_correct)
    te2_loss.append(test_loss), te2_correct.append(test_correct)
    
    
    print(f"Epoch {t+1}: Train_accuracy: {(100*train_correct):>0.2f}%, Train_loss: {train_loss:>8f}, Test_accuracy: {(100*test_correct):>0.2f}%, Test_loss: {test_loss:>8f}")
    
    if early_stopper.early_stop(test_loss): 
        print("Done!")
        break
# Out:
# Epoch 1: Train_accuracy: 30.92%, Train_loss: 0.008398, Test_accuracy: 34.76%, Test_loss: 0.008445
# Epoch 2: Train_accuracy: 36.15%, Train_loss: 0.008211, Test_accuracy: 36.14%, Test_loss: 0.008391
# Epoch 3: Train_accuracy: 39.45%, Train_loss: 0.008084, Test_accuracy: 40.81%, Test_loss: 0.008212
# Epoch 4: Train_accuracy: 40.14%, Train_loss: 0.008062, Test_accuracy: 38.52%, Test_loss: 0.008320
# Epoch 5: Train_accuracy: 40.38%, Train_loss: 0.008053, Test_accuracy: 41.58%, Test_loss: 0.008202
# Epoch 6: Train_accuracy: 41.11%, Train_loss: 0.008027, Test_accuracy: 40.87%, Test_loss: 0.008227
# Epoch 7: Train_accuracy: 41.07%, Train_loss: 0.008030, Test_accuracy: 40.39%, Test_loss: 0.008245
# Epoch 8: Train_accuracy: 41.18%, Train_loss: 0.008028, Test_accuracy: 39.48%, Test_loss: 0.008255
# Epoch 9: Train_accuracy: 40.54%, Train_loss: 0.008052, Test_accuracy: 41.02%, Test_loss: 0.008208
# Epoch 10: Train_accuracy: 38.88%, Train_loss: 0.008119, Test_accuracy: 37.82%, Test_loss: 0.008335
# Epoch 11: Train_accuracy: 38.67%, Train_loss: 0.008128, Test_accuracy: 37.44%, Test_loss: 0.008343
# Epoch 12: Train_accuracy: 38.66%, Train_loss: 0.008130, Test_accuracy: 38.36%, Test_loss: 0.008321
# Epoch 13: Train_accuracy: 38.54%, Train_loss: 0.008136, Test_accuracy: 39.86%, Test_loss: 0.008269
# Epoch 14: Train_accuracy: 38.18%, Train_loss: 0.008150, Test_accuracy: 35.93%, Test_loss: 0.008410
# Epoch 15: Train_accuracy: 36.11%, Train_loss: 0.008230, Test_accuracy: 34.89%, Test_loss: 0.008459
# Done!

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,8))
plt.plot(range(1,len(tr2_loss)+1),tr2_loss, label='Training droput')
plt.plot(range(1,len(te2_loss)+1),te2_loss,label='Validation dropout')

# find position of lowest validation loss
minposs = te2_loss.index(min(te2_loss))+1 
plt.axvline(minposs, linestyle='--', color='r',label='Early Stopping Checkpoint')

plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
model = NeuralNetwork_dropout(hidden_size=500, drop_out = dropouts)
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), weight_decay=weight_decay)
early_stopper = EarlyStopper(patience=patience, min_delta=0)

tr3_loss, tr3_correct = [], []
te3_loss, te3_correct = [], []
for t in range(max_epochs):
    train_loss, train_correct = train_loop(train_dataloader, model, loss_fn, optimizer)
    test_loss, test_correct = test_loop(test_dataloader, model, loss_fn)
    
    tr3_loss.append(train_loss), tr3_correct.append(train_correct)
    te3_loss.append(test_loss), te3_correct.append(test_correct)
    
    
    print(f"Epoch {t+1}: Train_accuracy: {(100*train_correct):>0.2f}%, Train_loss: {train_loss:>8f}, Test_accuracy: {(100*test_correct):>0.2f}%, Test_loss: {test_loss:>8f}")
    
    if early_stopper.early_stop(test_loss): 
        print("Done!")
        break
# Out:
# Epoch 1: Train_accuracy: 32.28%, Train_loss: 0.008346, Test_accuracy: 37.09%, Test_loss: 0.008356
# Epoch 2: Train_accuracy: 36.54%, Train_loss: 0.008190, Test_accuracy: 38.68%, Test_loss: 0.008272
# Epoch 3: Train_accuracy: 38.96%, Train_loss: 0.008097, Test_accuracy: 37.49%, Test_loss: 0.008311
# Epoch 4: Train_accuracy: 40.03%, Train_loss: 0.008061, Test_accuracy: 40.78%, Test_loss: 0.008204
# Epoch 5: Train_accuracy: 40.67%, Train_loss: 0.008028, Test_accuracy: 38.93%, Test_loss: 0.008262
# Epoch 6: Train_accuracy: 41.88%, Train_loss: 0.007992, Test_accuracy: 41.56%, Test_loss: 0.008164
# Epoch 7: Train_accuracy: 42.12%, Train_loss: 0.007979, Test_accuracy: 41.32%, Test_loss: 0.008177
# Epoch 8: Train_accuracy: 42.53%, Train_loss: 0.007966, Test_accuracy: 42.95%, Test_loss: 0.008123
# Epoch 9: Train_accuracy: 42.84%, Train_loss: 0.007953, Test_accuracy: 42.17%, Test_loss: 0.008152
# Epoch 10: Train_accuracy: 43.51%, Train_loss: 0.007927, Test_accuracy: 42.40%, Test_loss: 0.008139
# Epoch 11: Train_accuracy: 44.02%, Train_loss: 0.007907, Test_accuracy: 43.78%, Test_loss: 0.008078
# Epoch 12: Train_accuracy: 44.19%, Train_loss: 0.007903, Test_accuracy: 44.76%, Test_loss: 0.008047
# Epoch 13: Train_accuracy: 44.64%, Train_loss: 0.007882, Test_accuracy: 43.28%, Test_loss: 0.008099
# Epoch 14: Train_accuracy: 44.51%, Train_loss: 0.007891, Test_accuracy: 43.96%, Test_loss: 0.008072
# Epoch 15: Train_accuracy: 44.98%, Train_loss: 0.007874, Test_accuracy: 42.96%, Test_loss: 0.008128
# Epoch 16: Train_accuracy: 45.14%, Train_loss: 0.007869, Test_accuracy: 44.60%, Test_loss: 0.008054
# Epoch 17: Train_accuracy: 45.77%, Train_loss: 0.007842, Test_accuracy: 44.02%, Test_loss: 0.008065
# Epoch 18: Train_accuracy: 45.57%, Train_loss: 0.007857, Test_accuracy: 43.80%, Test_loss: 0.008083
# Epoch 19: Train_accuracy: 46.05%, Train_loss: 0.007831, Test_accuracy: 45.04%, Test_loss: 0.008029
# Epoch 20: Train_accuracy: 46.02%, Train_loss: 0.007832, Test_accuracy: 44.89%, Test_loss: 0.008050
# Epoch 21: Train_accuracy: 45.99%, Train_loss: 0.007838, Test_accuracy: 45.66%, Test_loss: 0.008035
# Epoch 22: Train_accuracy: 46.18%, Train_loss: 0.007828, Test_accuracy: 44.88%, Test_loss: 0.008037
# Epoch 23: Train_accuracy: 46.21%, Train_loss: 0.007827, Test_accuracy: 44.62%, Test_loss: 0.008053
# Epoch 24: Train_accuracy: 46.48%, Train_loss: 0.007820, Test_accuracy: 45.40%, Test_loss: 0.008022
# Epoch 25: Train_accuracy: 46.69%, Train_loss: 0.007808, Test_accuracy: 45.91%, Test_loss: 0.008008
# Epoch 26: Train_accuracy: 46.68%, Train_loss: 0.007811, Test_accuracy: 44.59%, Test_loss: 0.008055
# Epoch 27: Train_accuracy: 46.74%, Train_loss: 0.007809, Test_accuracy: 43.73%, Test_loss: 0.008089
# Epoch 28: Train_accuracy: 46.89%, Train_loss: 0.007802, Test_accuracy: 44.83%, Test_loss: 0.008043
# Epoch 29: Train_accuracy: 47.29%, Train_loss: 0.007789, Test_accuracy: 45.55%, Test_loss: 0.008018
# Epoch 30: Train_accuracy: 47.27%, Train_loss: 0.007791, Test_accuracy: 44.50%, Test_loss: 0.008055
# Epoch 31: Train_accuracy: 46.99%, Train_loss: 0.007800, Test_accuracy: 43.99%, Test_loss: 0.008066
# Epoch 32: Train_accuracy: 47.15%, Train_loss: 0.007796, Test_accuracy: 46.16%, Test_loss: 0.007986
# Epoch 33: Train_accuracy: 47.28%, Train_loss: 0.007789, Test_accuracy: 45.79%, Test_loss: 0.008004
# Epoch 34: Train_accuracy: 47.65%, Train_loss: 0.007773, Test_accuracy: 46.83%, Test_loss: 0.007973
# Epoch 35: Train_accuracy: 47.65%, Train_loss: 0.007773, Test_accuracy: 45.26%, Test_loss: 0.008035
# Epoch 36: Train_accuracy: 47.57%, Train_loss: 0.007780, Test_accuracy: 45.85%, Test_loss: 0.008014
# Epoch 37: Train_accuracy: 47.43%, Train_loss: 0.007784, Test_accuracy: 45.92%, Test_loss: 0.007992
# Epoch 38: Train_accuracy: 47.82%, Train_loss: 0.007769, Test_accuracy: 45.34%, Test_loss: 0.008016
# Epoch 39: Train_accuracy: 47.35%, Train_loss: 0.007786, Test_accuracy: 43.88%, Test_loss: 0.008090
# Epoch 40: Train_accuracy: 46.96%, Train_loss: 0.007798, Test_accuracy: 43.90%, Test_loss: 0.008075
# Epoch 41: Train_accuracy: 47.60%, Train_loss: 0.007771, Test_accuracy: 45.64%, Test_loss: 0.008020
# Epoch 42: Train_accuracy: 47.83%, Train_loss: 0.007772, Test_accuracy: 45.55%, Test_loss: 0.008017
# Epoch 43: Train_accuracy: 47.72%, Train_loss: 0.007770, Test_accuracy: 45.58%, Test_loss: 0.008022
# Epoch 44: Train_accuracy: 47.76%, Train_loss: 0.007769, Test_accuracy: 45.50%, Test_loss: 0.008013
# Done!

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,8))
plt.plot(range(1,len(tr3_loss)+1),tr3_loss, label='Training dropout + decay')
plt.plot(range(1,len(te3_loss)+1),te3_loss,label='Validation dropout + decay')

# find position of lowest validation loss
minposs = te3_loss.index(min(te3_loss))+1 
plt.axvline(minposs, linestyle='--', color='r',label='Early Stopping Checkpoint')

plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,8))
plt.plot(range(1,len(tr_loss)+1),tr_loss, linestyle = '--', color = 'y', label='Training original')
plt.plot(range(1,len(te_loss)+1),te_loss, color = 'y', label='Validation original')
plt.plot(range(1,len(tr1_loss)+1),tr1_loss, linestyle = '--', color = 'b', label='Training weight decay')
plt.plot(range(1,len(te1_loss)+1),te1_loss, color = 'b', label='Validation weight decay')
plt.plot(range(1,len(tr2_loss)+1),tr2_loss, linestyle = '--', color = 'g', label='Training dropouts')
plt.plot(range(1,len(te2_loss)+1),te2_loss, color = 'g', label='Validation dropouts')
plt.plot(range(1,len(tr3_loss)+1),tr3_loss, linestyle = '--', color = 'r', label='Training decay + dropouts')
plt.plot(range(1,len(te3_loss)+1),te3_loss, color = 'r', label='Validation decay + dropouts')

plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
