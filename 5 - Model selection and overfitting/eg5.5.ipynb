# %%
import torch
from torch import nn
import torchvision
import torchvision.transforms as transforms

import numpy as np

# %%
batch_size = 256
max_epochs = 100

patience = 10
dropouts = 0.1
hidden_size = 400
weight_decay = 0.001

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
train_dataloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
test_dataloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=2)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
class NeuralNetwork(nn.Module):
    def __init__(self, hidden_size=500):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(32*32*3, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, 10),
            nn.Softmax(dim=1)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

# %%
class NeuralNetwork_dropout(nn.Module):
    def __init__(self, hidden_size = 100, drop_out=0.5):
        super(NeuralNetwork_dropout, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(32*32*3, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, hidden_size),
            nn.ReLU(),
            nn.Dropout(p=drop_out),
            nn.Linear(hidden_size, 10),
            nn.Softmax(dim=1)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

# %%
def train_loop(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    train_loss, train_correct = 0, 0
    for batch, (X, y) in enumerate(dataloader):
        # Compute prediction and loss
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item()
        train_correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    
    train_loss /= size
    train_correct /=size

    return train_loss, train_correct

def test_loop(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, test_correct = 0, 0

    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            test_correct += (pred.argmax(1) == y).type(torch.float).sum().item()

    test_loss /= size
    test_correct /= size
    
    return test_loss, test_correct

# %%
class EarlyStopper:
    def __init__(self, patience=10, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.min_validation_loss = np.inf

    def early_stop(self, validation_loss):
        if validation_loss < self.min_validation_loss:
            self.min_validation_loss = validation_loss
            self.counter = 0
        elif validation_loss > (self.min_validation_loss + self.min_delta):
            self.counter += 1
            if self.counter >= self.patience:
                return True
        return False

# %%
model = NeuralNetwork(hidden_size=hidden_size)
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters())
early_stopper = EarlyStopper(patience=patience, min_delta=0)

tr_loss, tr_correct = [], []
te_loss, te_correct = [], []
for t in range(max_epochs):
    train_loss, train_correct = train_loop(train_dataloader, model, loss_fn, optimizer)
    test_loss, test_correct = test_loop(test_dataloader, model, loss_fn)
    
    tr_loss.append(train_loss), tr_correct.append(train_correct)
    te_loss.append(test_loss), te_correct.append(test_correct)
    
    
    print(f"Epoch {t+1}: Train_accuracy: {(100*train_correct):>0.2f}%, Train_loss: {train_loss:>8f}, Test_accuracy: {(100*test_correct):>0.2f}%, Test_loss: {test_loss:>8f}")
    
    if early_stopper.early_stop(test_loss): 
        print("Done!")
        break
# Out:
# Epoch 1: Train_accuracy: 33.62%, Train_loss: 0.008297, Test_accuracy: 38.48%, Test_loss: 0.008301
# Epoch 2: Train_accuracy: 39.76%, Train_loss: 0.008069, Test_accuracy: 39.79%, Test_loss: 0.008247
# Epoch 3: Train_accuracy: 41.63%, Train_loss: 0.007997, Test_accuracy: 41.87%, Test_loss: 0.008170
# Epoch 4: Train_accuracy: 43.45%, Train_loss: 0.007926, Test_accuracy: 41.57%, Test_loss: 0.008175
# Epoch 5: Train_accuracy: 43.83%, Train_loss: 0.007911, Test_accuracy: 43.73%, Test_loss: 0.008094
# Epoch 6: Train_accuracy: 45.55%, Train_loss: 0.007848, Test_accuracy: 45.16%, Test_loss: 0.008048
# Epoch 7: Train_accuracy: 46.14%, Train_loss: 0.007825, Test_accuracy: 43.82%, Test_loss: 0.008094
# Epoch 8: Train_accuracy: 46.20%, Train_loss: 0.007825, Test_accuracy: 43.90%, Test_loss: 0.008096
# Epoch 9: Train_accuracy: 46.63%, Train_loss: 0.007807, Test_accuracy: 44.34%, Test_loss: 0.008080
# Epoch 10: Train_accuracy: 46.74%, Train_loss: 0.007806, Test_accuracy: 42.03%, Test_loss: 0.008153
# Epoch 11: Train_accuracy: 46.23%, Train_loss: 0.007827, Test_accuracy: 44.55%, Test_loss: 0.008060
# Epoch 12: Train_accuracy: 46.60%, Train_loss: 0.007812, Test_accuracy: 45.29%, Test_loss: 0.008046
# Epoch 13: Train_accuracy: 46.97%, Train_loss: 0.007800, Test_accuracy: 44.87%, Test_loss: 0.008042
# Epoch 14: Train_accuracy: 47.00%, Train_loss: 0.007798, Test_accuracy: 44.90%, Test_loss: 0.008055
# Epoch 15: Train_accuracy: 47.64%, Train_loss: 0.007774, Test_accuracy: 45.50%, Test_loss: 0.008038
# Epoch 16: Train_accuracy: 47.44%, Train_loss: 0.007783, Test_accuracy: 45.62%, Test_loss: 0.008034
# Epoch 17: Train_accuracy: 46.30%, Train_loss: 0.007827, Test_accuracy: 43.64%, Test_loss: 0.008102
# Epoch 18: Train_accuracy: 45.84%, Train_loss: 0.007845, Test_accuracy: 44.73%, Test_loss: 0.008059
# Epoch 19: Train_accuracy: 46.66%, Train_loss: 0.007815, Test_accuracy: 45.30%, Test_loss: 0.008025
# Epoch 20: Train_accuracy: 47.40%, Train_loss: 0.007786, Test_accuracy: 43.15%, Test_loss: 0.008130
# Epoch 21: Train_accuracy: 46.19%, Train_loss: 0.007835, Test_accuracy: 41.91%, Test_loss: 0.008168
# Epoch 22: Train_accuracy: 46.81%, Train_loss: 0.007808, Test_accuracy: 45.53%, Test_loss: 0.008022
# Epoch 23: Train_accuracy: 46.16%, Train_loss: 0.007834, Test_accuracy: 42.96%, Test_loss: 0.008141
# Epoch 24: Train_accuracy: 46.01%, Train_loss: 0.007841, Test_accuracy: 43.91%, Test_loss: 0.008115
# Epoch 25: Train_accuracy: 46.19%, Train_loss: 0.007835, Test_accuracy: 43.83%, Test_loss: 0.008091
# Epoch 26: Train_accuracy: 46.82%, Train_loss: 0.007810, Test_accuracy: 42.27%, Test_loss: 0.008156
# Epoch 27: Train_accuracy: 45.42%, Train_loss: 0.007867, Test_accuracy: 40.31%, Test_loss: 0.008250
# Epoch 28: Train_accuracy: 44.12%, Train_loss: 0.007915, Test_accuracy: 43.83%, Test_loss: 0.008120
# Epoch 29: Train_accuracy: 43.38%, Train_loss: 0.007945, Test_accuracy: 39.59%, Test_loss: 0.008274
# Epoch 30: Train_accuracy: 42.45%, Train_loss: 0.007981, Test_accuracy: 41.54%, Test_loss: 0.008192
# Epoch 31: Train_accuracy: 41.74%, Train_loss: 0.008010, Test_accuracy: 39.70%, Test_loss: 0.008268
# Epoch 32: Train_accuracy: 41.58%, Train_loss: 0.008017, Test_accuracy: 41.98%, Test_loss: 0.008163
# Done!

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,8))
plt.plot(range(1,len(tr_loss)+1),tr_loss, label='Train Loss')
plt.plot(range(1,len(te_loss)+1),te_loss,label='Validation Loss')

# find position of lowest validation loss
minposs = te_loss.index(min(te_loss))+1 
plt.axvline(minposs, linestyle='--', color='r',label='Early Stopping Checkpoint')

plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
dropouts = 0.2
model = NeuralNetwork_dropout(hidden_size=hidden_size, drop_out = dropouts)
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), weight_decay = weight_decay)
early_stopper = EarlyStopper(patience=patience, min_delta=0)

tr2_loss, tr2_correct = [], []
te2_loss, te2_correct = [], []
for t in range(max_epochs):
    train_loss, train_correct = train_loop(train_dataloader, model, loss_fn, optimizer)
    test_loss, test_correct = test_loop(test_dataloader, model, loss_fn)
    
    tr2_loss.append(train_loss), tr2_correct.append(train_correct)
    te2_loss.append(test_loss), te2_correct.append(test_correct)
    
    
    print(f"Epoch {t+1}: Train_accuracy: {(100*train_correct):>0.2f}%, Train_loss: {train_loss:>8f}, Test_accuracy: {(100*test_correct):>0.2f}%, Test_loss: {test_loss:>8f}")
    
    if early_stopper.early_stop(test_loss): 
        print("Done!")
        break
# Out:
# Epoch 1: Train_accuracy: 31.98%, Train_loss: 0.008359, Test_accuracy: 32.92%, Test_loss: 0.008496
# Epoch 2: Train_accuracy: 37.00%, Train_loss: 0.008171, Test_accuracy: 36.53%, Test_loss: 0.008348
# Epoch 3: Train_accuracy: 38.93%, Train_loss: 0.008098, Test_accuracy: 39.50%, Test_loss: 0.008238
# Epoch 4: Train_accuracy: 41.04%, Train_loss: 0.008017, Test_accuracy: 41.13%, Test_loss: 0.008175
# Epoch 5: Train_accuracy: 42.30%, Train_loss: 0.007977, Test_accuracy: 41.54%, Test_loss: 0.008170
# Epoch 6: Train_accuracy: 43.28%, Train_loss: 0.007938, Test_accuracy: 42.38%, Test_loss: 0.008145
# Epoch 7: Train_accuracy: 44.16%, Train_loss: 0.007906, Test_accuracy: 43.90%, Test_loss: 0.008093
# Epoch 8: Train_accuracy: 44.88%, Train_loss: 0.007877, Test_accuracy: 43.19%, Test_loss: 0.008108
# Epoch 9: Train_accuracy: 45.29%, Train_loss: 0.007861, Test_accuracy: 44.66%, Test_loss: 0.008039
# Epoch 10: Train_accuracy: 45.82%, Train_loss: 0.007840, Test_accuracy: 44.00%, Test_loss: 0.008067
# Epoch 11: Train_accuracy: 46.60%, Train_loss: 0.007811, Test_accuracy: 45.16%, Test_loss: 0.008047
# Epoch 12: Train_accuracy: 47.12%, Train_loss: 0.007794, Test_accuracy: 44.87%, Test_loss: 0.008040
# Epoch 13: Train_accuracy: 47.67%, Train_loss: 0.007774, Test_accuracy: 44.99%, Test_loss: 0.008023
# Epoch 14: Train_accuracy: 47.94%, Train_loss: 0.007764, Test_accuracy: 45.83%, Test_loss: 0.008009
# Epoch 15: Train_accuracy: 48.17%, Train_loss: 0.007755, Test_accuracy: 46.64%, Test_loss: 0.007981
# Epoch 16: Train_accuracy: 48.91%, Train_loss: 0.007730, Test_accuracy: 46.50%, Test_loss: 0.007984
# Epoch 17: Train_accuracy: 49.17%, Train_loss: 0.007718, Test_accuracy: 46.52%, Test_loss: 0.007971
# Epoch 18: Train_accuracy: 49.61%, Train_loss: 0.007703, Test_accuracy: 47.33%, Test_loss: 0.007954
# Epoch 19: Train_accuracy: 49.84%, Train_loss: 0.007689, Test_accuracy: 47.39%, Test_loss: 0.007952
# Epoch 20: Train_accuracy: 50.32%, Train_loss: 0.007675, Test_accuracy: 47.01%, Test_loss: 0.007969
# Epoch 21: Train_accuracy: 50.54%, Train_loss: 0.007671, Test_accuracy: 46.79%, Test_loss: 0.007973
# Epoch 22: Train_accuracy: 50.79%, Train_loss: 0.007657, Test_accuracy: 46.28%, Test_loss: 0.007995
# Epoch 23: Train_accuracy: 50.55%, Train_loss: 0.007668, Test_accuracy: 47.56%, Test_loss: 0.007923
# Epoch 24: Train_accuracy: 51.10%, Train_loss: 0.007649, Test_accuracy: 47.51%, Test_loss: 0.007940
# Epoch 25: Train_accuracy: 50.95%, Train_loss: 0.007654, Test_accuracy: 47.02%, Test_loss: 0.007970
# Epoch 26: Train_accuracy: 51.22%, Train_loss: 0.007640, Test_accuracy: 46.81%, Test_loss: 0.007984
# Epoch 27: Train_accuracy: 51.29%, Train_loss: 0.007642, Test_accuracy: 48.55%, Test_loss: 0.007897
# Epoch 28: Train_accuracy: 51.63%, Train_loss: 0.007629, Test_accuracy: 48.34%, Test_loss: 0.007911
# Epoch 29: Train_accuracy: 51.71%, Train_loss: 0.007626, Test_accuracy: 48.11%, Test_loss: 0.007923
# Epoch 30: Train_accuracy: 52.01%, Train_loss: 0.007615, Test_accuracy: 48.04%, Test_loss: 0.007925
# Epoch 31: Train_accuracy: 52.30%, Train_loss: 0.007602, Test_accuracy: 48.71%, Test_loss: 0.007896
# Epoch 32: Train_accuracy: 52.02%, Train_loss: 0.007613, Test_accuracy: 48.68%, Test_loss: 0.007886
# Epoch 33: Train_accuracy: 52.07%, Train_loss: 0.007607, Test_accuracy: 49.31%, Test_loss: 0.007865
# Epoch 34: Train_accuracy: 52.79%, Train_loss: 0.007582, Test_accuracy: 48.32%, Test_loss: 0.007906
# Epoch 35: Train_accuracy: 52.53%, Train_loss: 0.007591, Test_accuracy: 47.89%, Test_loss: 0.007921
# Epoch 36: Train_accuracy: 53.03%, Train_loss: 0.007578, Test_accuracy: 48.04%, Test_loss: 0.007907
# Epoch 37: Train_accuracy: 53.13%, Train_loss: 0.007572, Test_accuracy: 47.93%, Test_loss: 0.007917
# Epoch 38: Train_accuracy: 52.71%, Train_loss: 0.007586, Test_accuracy: 48.47%, Test_loss: 0.007910
# Epoch 39: Train_accuracy: 52.49%, Train_loss: 0.007591, Test_accuracy: 47.95%, Test_loss: 0.007926
# Epoch 40: Train_accuracy: 53.10%, Train_loss: 0.007574, Test_accuracy: 48.27%, Test_loss: 0.007908
# Epoch 41: Train_accuracy: 53.27%, Train_loss: 0.007566, Test_accuracy: 48.71%, Test_loss: 0.007893
# Epoch 42: Train_accuracy: 53.46%, Train_loss: 0.007565, Test_accuracy: 48.26%, Test_loss: 0.007896
# Epoch 43: Train_accuracy: 52.94%, Train_loss: 0.007577, Test_accuracy: 49.50%, Test_loss: 0.007875
# Done!

# %%
import matplotlib.pyplot as plt

plt.plot(range(1,len(tr2_loss)+1),tr2_loss, label='Training droput')
plt.plot(range(1,len(te2_loss)+1),te2_loss,label='Validation dropout')

# find position of lowest validation loss
minposs = te2_loss.index(min(te2_loss))+1 
plt.axvline(minposs, linestyle='--', color='r',label='Early Stopping Checkpoint')

plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(range(1,len(tr_loss)+1),tr_loss, linestyle = '--', color = 'y', label='Training original')
plt.plot(range(1,len(te_loss)+1),te_loss, color = 'y', label='Validation original')
plt.plot(range(1,len(tr2_loss)+1),tr2_loss, linestyle = '--', color = 'g', label='Training dropouts')
plt.plot(range(1,len(te2_loss)+1),te2_loss, color = 'g', label='Validation dropouts')

plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
